# %%
df = pd.read_excel("Iadeler listesi.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15880 entries, 0 to 15879
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Type                 7940 non-null   object
#  1   nOrderId             7940 non-null   float64
#  2   cPostCode            7939 non-null   object
#  3   Customer ID          7940 non-null   object
#  4   ItemNumber           7938 non-null   object
#  5   ItemTitle            6276 non-null   object
#  6   dReceievedDate       7940 non-null   object
#  7   cCountry             7940 non-null   object
#  8   cCountryCode         7940 non-null   object
#  9   cCurrency            7940 non-null   object
#  10  source               7940 non-null   object
#  11  subsource            7932 non-null   object
#  12  Return Date          5102 non-null   object
#  13  ReturnQty            7940 non-null   float64
#  14  Category             2593 non-null   object
# ...

# %%
dfed = pd.DataFrame(df)

# %%
dfed.dropna(axis = 0, how = 'all', inplace = True)

# %%
dfed
# Out:
#                 Type  nOrderId cPostCode Customer ID  \
# 1           EXCHANGE  123242.0  CF11 0JE    C0012493
# 3           EXCHANGE  124273.0   HX4 9HP    C0000946
# 5             REFUND  100064.0  BT23 4PX    C0001051
# 7             REFUND  100557.0   KW1 4YL    C0001314
# 9             REFUND  100773.0   NG3 6PD    C0001313
# ...              ...       ...       ...         ...
# 15871  RETURNBOOKING  137836.0   wd187uh    C0030666
# 15873  RETURNBOOKING  138454.0   CV3 1NB    C0013520
# 15875  RETURNBOOKING  138459.0   WV1 3RN    C0005820
# 15877  RETURNBOOKING  138479.0   AL2 3LG    C0015078
# 15879  RETURNBOOKING  138479.0   AL2 3LG    C0015078
#
#                        ItemNumber                   ItemTitle  \
# 1                           49215         Caimas 2980 120x170
# 3                        49035-pr  Montana 3720 brown 160X230
# 5      153761726783-1958345997005                         NaN
# 7      153525972948-1992856209005                         NaN
# ...

# %%
dfed.reset_index(drop=True, inplace=True)

# %%
dfed.sample(11)
# Out:
#         Type  nOrderId cPostCode Customer ID        ItemNumber  \
# 2056  REFUND  143173.0  Redacted    C0000001              2679
# 4184  REFUND  174886.0  Redacted    C0000001              2994
# 592   REFUND  123054.0  Redacted    C0000001    38650200000000
# 561   REFUND  122703.0  Redacted    C0000001              2246
# 2117  REFUND  144337.0  CV37 7RD    C0009535              2899
# 4593  REFUND  179959.0    N1 8NY    C0025772              2485
# 5754  RETURN  126683.0  Redacted    C0000001             49216
# 5448  RETURN  120133.0  Redacted    C0000001          48897-my
# 2108  REFUND  144130.0  Redacted    C0000001              2584
# 1967  REFUND  141652.0  PE20 4ZD    C0000574  28409--LIN001005
# 3747  REFUND  169277.0     63263    C0001095       25762--2861
#
#                             ItemTitle       dReceievedDate        cCountry  \
# 2056             Marakech 430 120x170     31/03/2022 07:36  United Kingdom
# ...

# %%
dfed['RMA Actioned'].value_counts(dropna = False)
# Out:
# 1.0    7940
# Name: RMA Actioned, dtype: int64

# %%
dfed.drop(columns=['cCountryCode', 'RMA Actioned'], inplace=True)

# %%
dfed.head()
# Out:
#        Type  nOrderId cPostCode Customer ID                  ItemNumber  \
# 0  EXCHANGE  123242.0  CF11 0JE    C0012493                       49215
# 1  EXCHANGE  124273.0   HX4 9HP    C0000946                    49035-pr
# 2    REFUND  100064.0  BT23 4PX    C0001051  153761726783-1958345997005
# 3    REFUND  100557.0   KW1 4YL    C0001314  153525972948-1992856209005
# 4    REFUND  100773.0   NG3 6PD    C0001313  153525972948-1997358422005
#
#                     ItemTitle       dReceievedDate        cCountry cCurrency  \
# 0         Caimas 2980 120x170  2021-04-08 18:52:00  United Kingdom       GBP
# 1  Montana 3720 brown 160X230     25/08/2021 11:19  United Kingdom       GBP
# 2                         NaN     21/12/2019 13:45  United Kingdom       GBP
# 3                         NaN     29/03/2020 13:14  United Kingdom       GBP
# 4                         NaN  2020-08-04 11:57:00  United Kingdom       GBP
#
# ...

# %%
dfed.dReceievedDate = dfed.dReceievedDate.apply(pd.to_datetime)

# %%
dfed['Return Date'] = dfed['Return Date'].apply(pd.to_datetime)

# %%
dfed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7940 entries, 0 to 7939
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Type                 7940 non-null   object
#  1   nOrderId             7940 non-null   float64
#  2   cPostCode            7939 non-null   object
#  3   Customer ID          7940 non-null   object
#  4   ItemNumber           7938 non-null   object
#  5   ItemTitle            6276 non-null   object
#  6   dReceievedDate       7940 non-null   datetime64[ns]
#  7   cCountry             7940 non-null   object
#  8   cCurrency            7940 non-null   object
#  9   source               7940 non-null   object
#  10  subsource            7932 non-null   object
#  11  Return Date          5102 non-null   datetime64[ns]
#  12  ReturnQty            7940 non-null   float64
#  13  Category             2593 non-null   object
#  14  ResendOrExchangeQty  7940 non-null   float64
# ...

# %%
dfed.head(7)
# Out:
#        Type  nOrderId cPostCode Customer ID                  ItemNumber  \
# 0  EXCHANGE  123242.0  CF11 0JE    C0012493                       49215
# 1  EXCHANGE  124273.0   HX4 9HP    C0000946                    49035-pr
# 2    REFUND  100064.0  BT23 4PX    C0001051  153761726783-1958345997005
# 3    REFUND  100557.0   KW1 4YL    C0001314  153525972948-1992856209005
# 4    REFUND  100773.0   NG3 6PD    C0001313  153525972948-1997358422005
# 5    REFUND  100791.0   BR2 8JT    C0000586  153796239663-1997506107005
# 6    REFUND  100811.0    N8 7EB    C0000040                 5261--18186
#
#                     ItemTitle      dReceievedDate        cCountry cCurrency  \
# 0         Caimas 2980 120x170 2021-04-08 18:52:00  United Kingdom       GBP
# 1  Montana 3720 brown 160X230 2021-08-25 11:19:00  United Kingdom       GBP
# 2                         NaN 2019-12-21 13:45:00  United Kingdom       GBP
# 3                         NaN 2020-03-29 13:14:00  United Kingdom       GBP
# ...

# %%
dfed.isnull().sum()
# Out:
# Type                      0
# nOrderId                  0
# cPostCode                 1
# Customer ID               0
# ItemNumber                2
# ItemTitle              1664
# dReceievedDate            0
# cCountry                  0
# cCurrency                 0
# source                    0
# subsource                 8
# Return Date            2838
# ReturnQty                 0
# Category               5347
# ResendOrExchangeQty       0
# Refund Amount             0
# Return Reason          5436
# dtype: int64

# %%
dfed['source'].value_counts(dropna = False)
# Out:
# AMAZON            4731
# WOOCOMMERCE       2537
# EBAY               332
# ETSY               247
# WAYFAIRCHANNEL      70
# DIRECT              16
# AMAZON FBA           5
# OnBuy.com            2
# Name: source, dtype: int64

# %%
dfed['subsource'].value_counts(dropna = False)
# Out:
# Mynes Home Ltd              4717
# https://www.the-rugs.com    2539
# EBAY1                        332
# Etsy-TheRugs                 247
# EESER                         70
# Mynes Home Ltd Germany        10
# NaN                            8
# Mynes Home Ltd France          7
# Mynes Home Ltd.                4
# Mynes Home Ltd Spain           4
# Onbuy                          2
# Name: subsource, dtype: int64

# %%
dfed.groupby('subsource').sum()
# Out:
#                              nOrderId  ReturnQty  ResendOrExchangeQty  \
# subsource
# EBAY1                      46245592.0      114.0                  0.0
# EESER                      10848276.0        1.0                  0.0
# Etsy-TheRugs               37805058.0       90.0                  0.0
# Mynes Home Ltd            716092150.0     1614.0                  1.0
# Mynes Home Ltd France        933308.0        0.0                  0.0
# Mynes Home Ltd Germany      1232944.0        0.0                  0.0
# Mynes Home Ltd Spain         490219.0        0.0                  0.0
# Mynes Home Ltd.              436333.0        0.0                  0.0
# Onbuy                        308793.0        0.0                  0.0
# https://www.the-rugs.com  390189871.0      892.0                  2.0
#
#                           Refund Amount
# subsource
# EBAY1                      11154.300000
# EESER                       2181.572400
# Etsy-TheRugs               12265.570000
# ...

# %%
dfed.head()
# Out:
#        Type  nOrderId cPostCode Customer ID                  ItemNumber  \
# 0  EXCHANGE  123242.0  CF11 0JE    C0012493                       49215
# 1  EXCHANGE  124273.0   HX4 9HP    C0000946                    49035-pr
# 2    REFUND  100064.0  BT23 4PX    C0001051  153761726783-1958345997005
# 3    REFUND  100557.0   KW1 4YL    C0001314  153525972948-1992856209005
# 4    REFUND  100773.0   NG3 6PD    C0001313  153525972948-1997358422005
#
#                     ItemTitle      dReceievedDate        cCountry cCurrency  \
# 0         Caimas 2980 120x170 2021-04-08 18:52:00  United Kingdom       GBP
# 1  Montana 3720 brown 160X230 2021-08-25 11:19:00  United Kingdom       GBP
# 2                         NaN 2019-12-21 13:45:00  United Kingdom       GBP
# 3                         NaN 2020-03-29 13:14:00  United Kingdom       GBP
# 4                         NaN 2020-08-04 11:57:00  United Kingdom       GBP
#
#         source                 subsource         Return Date  ReturnQty  \
# ...

# %%
dfed.to_excel('iade_edali.xlsx')
